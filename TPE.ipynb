# %%
from wget import download
from os import path, listdir
from wget import download
from os import path, listdir


if not path.exists("online_shoppers_intention.csv"):
  download("https://raw.githubusercontent.com/Naay-Arenaza/TPE-Fundamentos-de-la-Ciencia-de-Datos/main/online_shoppers_intention.csv")
else:
  print("No vamos a bajar el archivo de casas porque ya existe!")


lista_archivos = listdir("./")
print(f"El contenido de la carpeta es: {lista_archivos}")
# Out:
# No vamos a bajar el archivo de casas porque ya existe!
# El contenido de la carpeta es: ['.ipynb_checkpoints', 'online_shoppers_intention_mod.csv', '.git', 'TPE.ipynb', 'online_shoppers_intention.csv', 'README.md']

# %%
import pandas as pd

raw_dataset = pd.read_csv("online_shoppers_intention.csv")

# %%
raw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
# ...

# %% [markdown]
# ## Tipado Incorrecto de Datos:

# %%
raw_dataset_mod = raw_dataset.copy()
raw_dataset_mod ["OperatingSystems"] = raw_dataset_mod ["OperatingSystems"].astype(object)
raw_dataset_mod ["Browser"] = raw_dataset_mod ["Browser"].astype(object)
raw_dataset_mod ["Region"] = raw_dataset_mod ["Region"].astype(object)
raw_dataset_mod ["TrafficType"] = raw_dataset_mod ["TrafficType"].astype(object)

raw_dataset_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  object
#  12  Browser                  12330 non-null  object
#  13  Region                   12330 non-null  object
# ...

# %% [markdown]
# ## Estadísticas Descriptivas del Conjunto de Datos Original

# %%
raw_dataset.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12330.000000             12330.000000   12330.000000
# mean         2.315166                80.818611       0.503569
# std          3.321784               176.779107       1.270156
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.500000       0.000000
# 75%          4.000000                93.256250       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12330.000000    12330.000000             12330.000000
# mean                34.472398       31.731468              1194.746220
# std                140.749294       44.475503              1913.669288
# min                  0.000000        0.000000                 0.000000
# ...

# %% [markdown]
# ## Formato Porcentajes

# %%
raw_dataset_mod["BounceRates"] = raw_dataset_mod["BounceRates"] * 100
raw_dataset_mod["ExitRates"] = raw_dataset_mod["ExitRates"] * 100

# %% [markdown]
# ## Eliminar Filas Duplicadas

# %%
raw_dataset_mod.duplicated().sum()
# Out:
# np.int64(125)

# %%
raw_dataset_mod = raw_dataset_mod.drop_duplicates()

# %% [markdown]
# ## Estadísticas Descriptivas del Conjunto de Datos Modificado + Analisis de cada una de las variables + Graficos

# %%
raw_dataset_mod.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12205.000000             12205.000000   12205.000000
# mean         2.338878                81.646331       0.508726
# std          3.330436               177.491845       1.275617
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 9.000000       0.000000
# 75%          4.000000                94.700000       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12205.000000    12205.000000             12205.000000
# mean                34.825454       32.045637              1206.982457
# std                141.424807       44.593649              1919.601400
# min                  0.000000        0.000000                 0.000000
# ...

# %%
raw_dataset_mod.describe().T
# Out:
#                            count         mean          std  min         25%  \
# Administrative           12205.0     2.338878     3.330436  0.0    0.000000
# Administrative_Duration  12205.0    81.646331   177.491845  0.0    0.000000
# Informational            12205.0     0.508726     1.275617  0.0    0.000000
# Informational_Duration   12205.0    34.825454   141.424807  0.0    0.000000
# ProductRelated           12205.0    32.045637    44.593649  0.0    8.000000
# ProductRelated_Duration  12205.0  1206.982457  1919.601400  0.0  193.000000
# BounceRates              12205.0     2.037032     4.525544  0.0    0.000000
# ExitRates                12205.0     4.146560     4.616270  0.0    1.423097
# PageValues               12205.0     5.949574    18.653671  0.0    0.000000
# SpecialDay               12205.0     0.061942     0.199666  0.0    0.000000
#
#                                 50%          75%           max
# Administrative             1.000000     4.000000     27.000000
# ...

# %% [markdown]
# ### Analisis de las variables numericas + Graficos

# %% [markdown]
# #### Administrative

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'Administrative'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,         
            meanprops={"marker":"^",      
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                       "markersize":"10"}
           )
plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Numero de Páginas', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
bins_manuales = [0, 5, 10, 15, 20, 28] # 5 rangos, el max es ~27

plt.hist(raw_dataset["Administrative"], bins=bins_manuales, rwidth=0.9)

plt.xlabel("Número de Páginas Administrativas")
plt.ylabel("Frecuencia (Cantidad de Sesiones)")

plt.title("Histograma de Páginas Administrativas")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### Administrative_Duration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'Administrative_Duration'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,         
            meanprops={"marker":"^",      
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Duración (segundos)', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

columna = 'Administrative_Duration'

plt.figure() 

plt.hist(raw_dataset[columna], bins=50, rwidth=0.9, color='blue')
plt.yscale('log')

plt.xlabel(f"Valor de {columna} (segundos)")
plt.ylabel("Frecuencia (Escala Logarítmica)")
plt.title(f"Histograma de {columna} (Escala Log)")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### Informational

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'Informational'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,        
            meanprops={"marker":"^",     
                       "markerfacecolor":"green", 
                       "markeredgecolor":"green",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Numero de Páginas', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['Informational'], bins=50, rwidth=0.9)

plt.yscale('log')


plt.xlabel(f"Cantidad de paginas visitadas")
plt.ylabel("Cantidad de Registros")
plt.title(f"Histograma de visitas a paginas tipo Informational")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### Informational_Duration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'Informational_Duration'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,       
            meanprops={"marker":"^",      
                       "markerfacecolor":"pink", 
                       "markeredgecolor":"pink",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Duración (segundos)', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['Informational_Duration'], bins=50, rwidth=0.9)

plt.yscale('log')

plt.xlabel(f"Tiempo (en segundos)")
plt.ylabel("Cantidad de Registros")
plt.title(f"Histograma de tiempo de visita a paginas tipo Informational_Duration")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### ProductRelated

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'ProductRelated'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,        
            meanprops={"marker":"^",      
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Numero de Paginas', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['ProductRelated'], bins=50, rwidth=0.9)

plt.yscale('log')


plt.xlabel(f"Cantidad de paginas visitadas")
plt.ylabel("Cantidad de Registros")
plt.title(f"Histograma de visitas a paginas tipo ProductRelated")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### ProductRelated_Duration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'ProductRelated_Duration'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,         
            meanprops={"marker":"^",      
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Duración (segundos)', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['ProductRelated_Duration'], bins=50, rwidth=0.9)

plt.yscale('log')

plt.xlabel(f"Tiempo (en segundos)")
    
plt.ylabel("Cantidad de Registros")
plt.title(f"Histograma de tiempo de visita a paginas tipo ProductRelated_Duration")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### BounceRates

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'BounceRates'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,        
            meanprops={"marker":"^",      
                       "markerfacecolor":"green", 
                       "markeredgecolor":"green",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Porcentaje', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

columna = 'BounceRates'

plt.hist(raw_dataset_mod[columna], bins=30, rwidth=0.9, color='blue')
    
plt.xlabel("Pocentaje")
plt.ylabel("Cantidad de sesiones")
plt.title(f"Histograma de {columna}")
    
plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### ExitRates

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'ExitRates'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar,  
            showmeans=True,       
            meanprops={"marker":"^",      
                       "markerfacecolor":"white", 
                       "markeredgecolor":"white",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Porcentaje', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

columna = 'ExitRates'

plt.hist(raw_dataset_mod[columna], bins=30, rwidth=0.9, color='blue')
    
plt.xlabel("Pocentaje")
plt.ylabel("Cantidad de sesiones")
plt.title(f"Histograma de {columna}")
    
plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### PageValues

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'PageValues'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar, 
            showmeans=True,        
            meanprops={"marker":"^",     
                       "markerfacecolor":"pink", 
                       "markeredgecolor":"pink",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Promedio', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['PageValues'], bins=50, rwidth=0.9)

plt.yscale('log')
plt.xlabel(f"Valor PageValue")
plt.ylabel("Cantidad de Registros")
plt.title(f"Histograma Page Value")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# #### SpecialDay

# %%
import matplotlib.pyplot as plt
import seaborn as sns

variable_a_analizar = 'SpecialDay'

plt.figure(figsize=(8, 7))

sns.boxplot(data=raw_dataset_mod, 
            y=variable_a_analizar, 
            showmeans=True,        
            meanprops={"marker":"^",      
                       "markerfacecolor":"green", 
                       "markeredgecolor":"green",
                       "markersize":"10"}
           )

plt.title(f'Boxplot de {variable_a_analizar}', fontsize=14)
plt.ylabel('Probabilidad de compra en SpecialDay', fontsize=12)

plt.xlabel(None)
plt.xticks([]) 

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.hist(raw_dataset_mod['SpecialDay'], bins=50, rwidth=0.9)

plt.xlabel(f"Probabilidad de compra en SpecialDay")
plt.ylabel("Cantidad de registros")
plt.title(f"Histograma SpecialDay")

plt.grid(axis='y', alpha=0.7) 
plt.show()

# %% [markdown]
# ## Granularidad innecesaria

# %% [markdown]
# A partir del box Plot realizado en la seccion anterior + este grafico de barras podemos observar que la gran mayoria de casos el valor que se toma es 0.0

# %%
raw_dataset_mod ["SpecialDay"] = raw_dataset_mod ["SpecialDay"].astype(bool)

# %%
raw_dataset_mod['SpecialDay'].value_counts()
# Out:
# SpecialDay
# False    10956
# True      1249
# Name: count, dtype: int64

# %%
raw_dataset_mod.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12205.000000             12205.000000   12205.000000
# mean         2.338878                81.646331       0.508726
# std          3.330436               177.491845       1.275617
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 9.000000       0.000000
# 75%          4.000000                94.700000       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12205.000000    12205.000000             12205.000000
# mean                34.825454       32.045637              1206.982457
# std                141.424807       44.593649              1919.601400
# min                  0.000000        0.000000                 0.000000
# ...

# %% [markdown]
# Al realizar este cambiamo, observamos que quedan filas duplicadas por lo tanto, volvemos a realizar la eliminacion de las mismas.

# %%
raw_dataset_mod.duplicated().sum()
# Out:
# np.int64(5)

# %%
raw_dataset_mod = raw_dataset_mod.drop_duplicates()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='SpecialDay',
    order=raw_dataset_mod['SpecialDay'].value_counts().index
)

plt.title('Frecuencia de Sesiones por SpecialDay')
plt.xlabel('SpecialDay')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %% [markdown]
# ## Analisis de variables categoricas + Modificacion de las misma

# %% [markdown]
# ### Analisis de la variable Month + modificacion

# %%
raw_dataset_mod['Month'].value_counts()
# Out:
# Month
# May     3325
# Nov     2982
# Mar     1860
# Dec     1706
# Oct      549
# Sep      448
# Aug      433
# Jul      432
# June     285
# Feb      180
# Name: count, dtype: int64

# %%
raw_dataset_mod['Month'] = raw_dataset_mod['Month'].replace('June', 'Jun')
raw_dataset_mod['Month'].value_counts()
# Out:
# Month
# May    3325
# Nov    2982
# Mar    1860
# Dec    1706
# Oct     549
# Sep     448
# Aug     433
# Jul     432
# Jun     285
# Feb     180
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='Month',
    order=raw_dataset_mod['Month'].value_counts().index
)

plt.title('Frecuencia de Sesiones por Month')
plt.xlabel('Month')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 7))

sns.countplot(
    data=raw_dataset_mod,
    x='Month',
    hue='Revenue', 
    order=raw_dataset_mod['Month'].value_counts().index
)

plt.title('Frecuencia de Compra (Revenue) por Month')
plt.xlabel('Month')
plt.ylabel('Cantidad de Sesiones')
plt.legend(title='Compró (Revenue)')

# %% [markdown]
# ### Analisis de la variable VisitorType + Modificacion

# %%
raw_dataset_mod['VisitorType'].value_counts()
# Out:
# VisitorType
# Returning_Visitor    10426
# New_Visitor           1693
# Other                   81
# Name: count, dtype: int64

# %%
raw_dataset_mod = raw_dataset_mod[raw_dataset_mod['VisitorType'] != 'Other']
raw_dataset_mod['VisitorType'].value_counts()
# Out:
# VisitorType
# Returning_Visitor    10426
# New_Visitor           1693
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='VisitorType',
    order=raw_dataset_mod['VisitorType'].value_counts().index
)

plt.title('Frecuencia de Sesiones por VisitorType')
plt.xlabel('VisitorType')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 7))

sns.countplot(
    data=raw_dataset_mod,
    x='VisitorType',
    hue='Revenue', 
    order=raw_dataset_mod['VisitorType'].value_counts().index
)

plt.title('Frecuencia de Compra (Revenue) por VisitorType')
plt.xlabel('VisitorType')
plt.ylabel('Cantidad de Sesiones')
plt.legend(title='Compró (Revenue)')

# %% [markdown]
# ### Analisis de la variable OperatingSystems

# %%
raw_dataset_mod['OperatingSystems'].value_counts()
# Out:
# OperatingSystems
# 2    6522
# 1    2541
# 3    2521
# 4     478
# 8      25
# 6      19
# 7       7
# 5       6
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='OperatingSystems',
    order=raw_dataset_mod['OperatingSystems'].value_counts().index
)

plt.title('Frecuencia de Sesiones por OperatingSystems')
plt.xlabel('OperatingSystems')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 7))

sns.countplot(
    data=raw_dataset_mod,
    x='OperatingSystems',
    hue='Revenue', 
    order=raw_dataset_mod['OperatingSystems'].value_counts().index
)

plt.title('Frecuencia de Compra (Revenue) por OperatingSystems')
plt.xlabel('OperatingSystems')
plt.ylabel('Cantidad de Sesiones')
plt.legend(title='Compró (Revenue)')

# %% [markdown]
# ### Analisis de la variable Browser

# %%
raw_dataset_mod['Browser'].value_counts()
# Out:
# Browser
# 2     7940
# 1     2456
# 4      733
# 5      465
# 6      174
# 10     162
# 8      135
# 3      105
# 7       49
# 12      10
# 13       9
# 11       6
# 9        1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='Browser',
    order=raw_dataset_mod['Browser'].value_counts().index
)

plt.title('Frecuencia de Sesiones por Browser')
plt.xlabel('Browser')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %% [markdown]
# ### Analisis de la variable TrafficType

# %%
raw_dataset_mod['TrafficType'].value_counts()
# Out:
# TrafficType
# 2     3902
# 1     2444
# 3     2045
# 4     1069
# 13     737
# 10     447
# 6      443
# 8      342
# 5      259
# 11     246
# 20     146
# 9       42
# 7       40
# 15      38
# 19      17
# 14      13
# 18      10
# 16       3
# 12       1
# 17       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='TrafficType',
    order=raw_dataset_mod['TrafficType'].value_counts().index
)

plt.title('Frecuencia de Sesiones por TrafficType')
plt.xlabel('TrafficType')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

crosstab_data = pd.crosstab(raw_dataset_mod['TrafficType'], raw_dataset_mod['Browser'])

plt.figure(figsize=(12, 8))
sns.heatmap(
    crosstab_data,
    annot=True,    
    fmt='d',        
    cmap='coolwarm'  
)

plt.title('Heatmap de Frecuencia: TrafficType vs. Browser')
plt.xlabel('Browser')
plt.ylabel('TrafficType')
# Out:
# Text(120.72222222222221, 0.5, 'TrafficType')

# %% [markdown]
# ### Analisis de la variable Region

# %%
raw_dataset_mod['Region'].value_counts()
# Out:
# Region
# 1    4772
# 3    2395
# 4    1177
# 2    1131
# 6     804
# 7     759
# 9     456
# 8     433
# 5     318
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='Region',
    order=raw_dataset_mod['Region'].value_counts().index
)

plt.title('Frecuencia de Sesiones por Region')
plt.xlabel('Region')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 7))

sns.countplot(
    data=raw_dataset_mod,
    x='Region',
    hue='Revenue', 
    order=raw_dataset_mod['Region'].value_counts().index
)

plt.title('Frecuencia de Compra (Revenue) por Region')
plt.xlabel('Region')
plt.ylabel('Cantidad de Sesiones')
plt.legend(title='Compró (Revenue)')

# %% [markdown]
# ### Analisis de la variable Weekend

# %%
raw_dataset_mod['Weekend'].value_counts()
# Out:
# Weekend
# False    9384
# True     2861
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='Weekend',
    order=raw_dataset_mod['Weekend'].value_counts().index
)

plt.title('Frecuencia de Sesiones por Weekend')
plt.xlabel('Weekend')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 7))

sns.countplot(
    data=raw_dataset_mod,
    x='Weekend',
    hue='Revenue',
    order=raw_dataset_mod['Weekend'].value_counts().index
)

plt.title('Frecuencia de Compra (Revenue) por Weekend')
plt.xlabel('Weekend')
plt.ylabel('Cantidad de Sesiones')
plt.legend(title='Compró (Revenue)')

# %% [markdown]
# ### Analisis de la variable Revenue

# %%
raw_dataset_mod['Revenue'].value_counts()
# Out:
# Revenue
# False    10353
# True      1892
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10, 6))

sns.countplot(
    data=raw_dataset_mod,
    x='Revenue',
    order=raw_dataset_mod['Revenue'].value_counts().index
)

plt.title('Frecuencia de Sesiones por Revenue')
plt.xlabel('Revenue')
plt.ylabel('Cantidad de Sesiones (Frecuencia)')
# Out:
# Text(0, 0.5, 'Cantidad de Sesiones (Frecuencia)')

# %% [markdown]
# ## Procesamiento Outliers

# %%
raw_dataset_mod.describe().T
# Out:
#                            count         mean          std  min         25%  \
# Administrative           12119.0     2.345160     3.334828  0.0    0.000000
# Administrative_Duration  12119.0    81.785984   177.300976  0.0    0.000000
# Informational            12119.0     0.511098     1.278520  0.0    0.000000
# Informational_Duration   12119.0    34.990626   141.824727  0.0    0.000000
# ProductRelated           12119.0    32.185411    44.667644  0.0    8.000000
# ProductRelated_Duration  12119.0  1211.546867  1922.747900  0.0  196.416667
# BounceRates              12119.0     2.022798     4.488808  0.0    0.000000
# ExitRates                12119.0     4.129903     4.588686  0.0    1.426082
# PageValues               12119.0     5.864200    18.159499  0.0    0.000000
#
#                                 50%          75%           max
# Administrative             1.000000     4.000000     27.000000
# Administrative_Duration    9.500000    95.000000   3398.750000
# ...

# %%
import numpy as np

cols_to_cap = [
    'Administrative', 'Administrative_Duration',
    'Informational', 'Informational_Duration',
    'ProductRelated', 'ProductRelated_Duration'
]

caps = raw_dataset_mod[cols_to_cap].quantile(0.99)

for col in cols_to_cap:
    print(f"{col}: {caps[col]:.2f}")

for col in cols_to_cap:
    raw_dataset_mod[col] = raw_dataset_mod[col].clip(upper=caps[col])

raw_dataset_mod[cols_to_cap].describe()
# Out:
# Administrative: 14.00
# Administrative_Duration: 837.67
# Informational: 6.00
# Informational_Duration: 722.83
# ProductRelated: 221.00
# ProductRelated_Duration: 8703.92
#        Administrative  Administrative_Duration  Informational  \
# count    12119.000000             12119.000000   12119.000000
# mean         2.315290                77.185506       0.492697
# std          3.202912               142.712723       1.156620
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 9.500000       0.000000
# 75%          4.000000                95.000000       0.000000
# max         14.000000               837.672000       6.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration
# count            12119.000000    12119.000000             12119.000000
# mean                30.836692       31.261078              1168.925364
# ...

# %%
raw_dataset_mod.describe().T
# Out:
#                            count         mean          std  min         25%  \
# Administrative           12119.0     2.315290     3.202912  0.0    0.000000
# Administrative_Duration  12119.0    77.185506   142.712723  0.0    0.000000
# Informational            12119.0     0.492697     1.156620  0.0    0.000000
# Informational_Duration   12119.0    30.836692   105.541565  0.0    0.000000
# ProductRelated           12119.0    31.261078    38.372786  0.0    8.000000
# ProductRelated_Duration  12119.0  1168.925364  1557.227130  0.0  196.416667
# BounceRates              12119.0     2.022798     4.488808  0.0    0.000000
# ExitRates                12119.0     4.129903     4.588686  0.0    1.426082
# PageValues               12119.0     5.864200    18.159499  0.0    0.000000
#
#                                 50%          75%          max
# Administrative             1.000000     4.000000    14.000000
# Administrative_Duration    9.500000    95.000000   837.672000
# ...

# %% [markdown]
# # Hipotesis

# %% [markdown]
# ## Hipotesis 1 / Univariada

# %% [markdown]
# #H₀: La proporción de visitas en mayo es igual o menor a 30%.

# %% [markdown]
# #H₁: La proporción de visitas en mayo es mayor que 30%.

# %%
import math
import numpy as np
from scipy import stats
from statsmodels.stats.proportion import proportion_confint

total = raw_dataset_mod["Month"].count()
conteo_por_mes = raw_dataset_mod["Month"].value_counts()
Mayo_total = conteo_por_mes["May"]
p0=0.30 
p_obs=Mayo_total/total 

print(f"Total: {total}")
print(f"Visitas en May: {Mayo_total}")
print(f"Proporción observada: {p_obs:.4f}")
print(f"Proporción H0 (p0): {p0:.2f}")
if (p_obs < p0):
    print("\nConclusión: Se RECHAZA H1")
else:
    print("\nConclusión: Se RECHAZA H0")
# Out:
# Total: 12119
# Visitas en May: 3325
# Proporción observada: 0.2744
# Proporción H0 (p0): 0.30
#
# Conclusión: Se RECHAZA H1

# %% [markdown]
# ### Graficos

# %%
meses_num = {"Jan":1, "Feb":2, "Mar":3, "Apr":4, "May":5, "Jun":6,"Jul":7, "Aug":8, "Sep":9, "Oct":10, "Nov":11, "Dec":12}
conteo = raw_dataset_mod['Month'].value_counts().reindex(meses_num.keys())
colors = ["#E4C200" if Month == "May" else 'gray' for Month in conteo.index]
bars=plt.bar(conteo.index, conteo.values/total*100,color=colors)
plt.xlabel('Mes')
plt.ylabel('Porcentaje')
plt.title('Porcentaje de visitas por mes')
plt.xticks(rotation=45)
for bar in bars:
    height = bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height,
    f"{height:.1f}",  
    ha='center',
    va='bottom'
)
plt.show()
bars=plt.bar(conteo.index, conteo.values,color=colors)
plt.xlabel('Mes')
plt.ylabel('Frecuencia')
plt.title('Visitas por mes')
plt.xticks(rotation=45)
for bar in bars:
    height = bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height,
    f"{height:.0f}",  
    ha='center',
    va='bottom'
)
plt.show()

# %% [markdown]
# ## Hipotesis 2 / Bivariada

# %% [markdown]
# H₀: El tipo de cliente es independiente de la compra.

# %% [markdown]
# H₁: Existe relación entre tipo de cliente y la compra.

# %%
import math
import numpy as np
from scipy import stats
from scipy.stats import chi2_contingency

tabla = pd.crosstab(raw_dataset_mod["VisitorType"], raw_dataset_mod["Revenue"])
chi2, p_value, df, esperado = chi2_contingency(tabla)

print("Chi2 calculado:", chi2)
print("p-value:", p_value)
print("Grados de libertad:", df)
print("Frecuencias observadas:\n", tabla.values)
print("Frecuencias esperadas:\n", esperado)

alpha = 0.05
if p_value < alpha:
    print("\nConclusión: Se RECHAZA H0 → Existe relación entre VisitorType y Revenue.")
else:
    print("\nConclusión: NO se rechaza H0 → Son independientes.")
# Out:
# Chi2 calculado: 128.76973995695352
# p-value: 7.616051258500072e-30
# Grados de libertad: 1
# Frecuencias observadas:
#  [[1271  422]
#  [8956 1470]]
# Frecuencias esperadas:
#  [[1428.69139368  264.30860632]
#  [8798.30860632 1627.69139368]]
#
# Conclusión: Se RECHAZA H0 → Existe relación entre VisitorType y Revenue.

# %% [markdown]
# ### Graficas

# %%
tabla_prop = tabla.div(tabla.sum(axis=1), axis=0)
ax = tabla_prop.plot(kind="bar", stacked=True)
for i, fila in enumerate(tabla_prop.values):
    acumulado = 0
    for j, valor in enumerate(fila):
        plt.text(
            i,                     
            acumulado + valor/2,   
            f"{valor*100:.1f}%",   
            ha="center",
            va="center",
            fontweight='bold',
            color="Black"
        )
        acumulado += valor
plt.title("Tipo de visita vs Revenue (Porcentaje)")
plt.xlabel("Tipo de Visitante")
plt.ylabel("Proporción")
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.show()

conteo_true = pd.crosstab(raw_dataset_mod["VisitorType"], raw_dataset_mod["Revenue"])[True]
bars=plt.bar(conteo_true.index, conteo_true.values,color="#FF9B49")
plt.ylabel('Cantidad')
plt.xlabel('Tipo')
plt.title('Revenue por Tipo')
plt.xticks(rotation=45)
for bar in bars:
    height = bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height,
    f"{height:.0f}", 
    ha='center',
    va='bottom'
)
plt.show()


conteo = raw_dataset_mod['VisitorType'].value_counts()
bars=plt.bar(conteo.index, conteo.values,color="#2200E4")
plt.ylabel('Cantidad')
plt.xlabel('Tipo')
plt.title('Visitas por tipo')
plt.xticks(rotation=45)
for bar in bars:
    height = bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height,
    f"{height:.0f}",  
    ha='center',
    va='bottom'
)
plt.show()

conteo = raw_dataset_mod['Revenue'].value_counts()
bars=plt.bar(conteo.index, conteo.values,color="#E46700")
plt.ylabel('Cantidad')
plt.title('Revenue')
plt.xticks([0, 1], ["False", "True"])
for bar in bars:
    height = bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height,
    f"{height:.0f}",   
    ha='center',
    va='bottom'
)
plt.show()

# %% [markdown]
# ## Hipotesis 3 / Univariada

# %% [markdown]
# H₀: El promedio de BR es igual o menor al umbral de 2%.

# %% [markdown]
# H₁: El promedio de BR es mayor que el umbral de 2%.

# %%
import numpy as np
from scipy import stats
import pandas as pd

mu_0 = 2.0 

alpha = 0.05

columna_datos = raw_dataset_mod['BounceRates']

t_stat, p_value_unilateral = stats.ttest_1samp(
    columna_datos.dropna(), 
    popmean=mu_0,
    alternative='greater'
)

n_muestras = columna_datos.count()
df_test = n_muestras - 1 

print(f"Grados de libertad (df = n-1): {df_test}")
print(f"Estadístico t: {t_stat:.4f}")
print(f"p-value unilateral (H1: μ > μ₀): {p_value_unilateral:.6f}")
print(f"--------------------------------------------------")

if p_value_unilateral < alpha:
    print("Decisión: Se rechaza la Hipótesis Nula (H₀).")
    print("Conclusión: Existe evidencia estadística para afirmar que el promedio del Bounce Rate supera el 2%.")
else:
    print("Decisión: No se rechaza la Hipótesis Nula (H₀).")
    print("Conclusión: No existe evidencia estadística significativa para afirmar que el promedio del Bounce Rate supere el 2%.")
# Out:
# Grados de libertad (df = n-1): 12118
# Estadístico t: 0.5591
# p-value unilateral (H1: μ > μ₀): 0.288050
# --------------------------------------------------
# Decisión: No se rechaza la Hipótesis Nula (H₀).
# Conclusión: No existe evidencia estadística significativa para afirmar que el promedio del Bounce Rate supere el 2%.

# %% [markdown]
# ### Graficos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

mu_0 = 2.0 

plt.figure(figsize=(10, 6))

plt.hist(columna_datos, bins=30, color="#13E400", edgecolor='black', alpha=0.7)

plt.axvline(mu_0, color='red', linestyle='--', linewidth=2, 
            label=fr'Umbral de Referencia ($\mu_0$ = {mu_0}%)')

plt.axvline(columna_datos.mean(), color='blue', linestyle='-', linewidth=2, 
            label=fr'Media Muestral ($\bar{{x}}$ = {columna_datos.mean():.4f}%)')

plt.title("Distribución de la Tasa de Rebote (Bounce Rates)", fontsize=15)
plt.xlabel("Tasa de Rebote (%)", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)
plt.legend()
plt.grid(axis='y', alpha=0.5)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mu_0 = 2.0 
plt.figure(figsize=(8, 6))

sns.boxplot(x=columna_datos, color='lightblue', width=0.3)

plt.axvline(mu_0, color='red', linestyle='--', linewidth=2, 
            label=fr'Umbral de Referencia ($\mu_0$ = {mu_0}%)')

plt.axvline(columna_datos.mean(), color='green', linestyle='-', linewidth=2, 
            label=fr'Media Muestral ({columna_datos.mean():.4f}%)')

plt.title('Distribución de la Tasa de Rebote (Bounce Rate)', fontsize=14)
plt.xlabel('Tasa de Rebote (%)', fontsize=12)
plt.legend()
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.xlim(columna_datos.quantile(0.01), columna_datos.quantile(0.99))

plt.show()

# %% [markdown]
# ## Hipotesis 4 / Bivariada

# %% [markdown]
# H₀: No existe diferencia en la cantidad de páginas de productos visitadas entre días especiales y días normales, o la media es menor en días especiales.

# %% [markdown]
# H₁: Sí existe relación entre ambas variables

# %%
from os import path, listdir
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

grupo_sd1 = raw_dataset_mod[raw_dataset_mod["SpecialDay"] == True]["ProductRelated"]
grupo_sd0 = raw_dataset_mod[raw_dataset_mod["SpecialDay"] == False]["ProductRelated"]

stat, p_valor = mannwhitneyu(grupo_sd1, grupo_sd0, alternative='greater')

print("Estadístico U:", stat)
print("p-valor:", p_valor)

alpha = 0.05

if p_valor < alpha:
    print("Se rechaza H0: los días especiales tienen MÁS visitas a productos que los días normales.")
else:
    print("No se rechaza H0: no hay evidencia de que los días especiales tengan más visitas a productos que los días normales.")
# Out:
# Estadístico U: 6403836.5
# p-valor: 0.9989790769721106
# No se rechaza H0: no hay evidencia de que los días especiales tengan más visitas a productos que los días normales.

# %% [markdown]
# ### Graficos

# %%
plt.figure(figsize=(7,5))
plt.hist(grupo_sd0, bins=20, alpha=0.5, label="SpecialDay = False")
plt.hist(grupo_sd1, bins=20, alpha=0.5, label="SpecialDay = True")
plt.title("Distribución de ProductRelated por tipo de día")
plt.xlabel("ProductRelated")
plt.ylabel("Frecuencia")
plt.legend()
plt.show()

# %% [markdown]
# ## Hipotesis 5 / Multivariada

# %% [markdown]
# H₀: No existe una relación significativa entre el crecimiento de ProductRelated_Duration y el decrecimiento de BounceRates con Revenue. No existe una relación significativa entre el crecimiento de ProductRelated_Duration y el decrecimiento de BounceRates con Revenue.

# %% [markdown]
# H₁: Existe una relación en cuanto al crecimiento de ProductRelated_Duration (tiempo en productos) combinado con un bajo BounceRates (tasa de rebote) que predecirá una probabilidad mucho mayor de Revenue (compra).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from wget import download
from os import path, listdir

calculo_hipotesis = raw_dataset_mod.groupby('Revenue')[['ProductRelated_Duration', 'BounceRates']].mean()
print(calculo_hipotesis)

independientes = ['ProductRelated_Duration', 'BounceRates']
dependiente = 'Revenue'
X = raw_dataset_mod[independientes]
y = raw_dataset_mod[dependiente]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_const = sm.add_constant(X_scaled)

modelo = sm.Logit(y,X_scaled_const)
resultado = modelo.fit()

tabla = pd.DataFrame({
    "Coeficiente": resultado.params,
    "P-Value": resultado.pvalues
})

tabla.index = ['c', 'ProductRelated_Duration', 'BounceRates']
print(tabla)
# Out:
#          ProductRelated_Duration  BounceRates
# Revenue
# False                1051.734154     2.301693
# True                 1802.389686     0.515260
# Optimization terminated successfully.
#          Current function value: 0.403965
#          Iterations 9
#                          Coeficiente       P-Value
# c                          -2.092000  0.000000e+00
# ProductRelated_Duration     0.322250  3.178826e-53
# BounceRates                -1.470409  2.385674e-38

# %% [markdown]
# ### Graficas

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Revenue', y='ProductRelated_Duration', data=raw_dataset_mod)
plt.title('Duración en Productos vs. Compra')
plt.xlabel('Generó Compra (Revenue)')
plt.ylabel('Duración en Productos (segundos)')
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(x='Revenue', y='BounceRates', data=raw_dataset_mod)
plt.title('Tasa de Rebote vs. Compra')
plt.xlabel('Generó Compra (Revenue)')
plt.ylabel('Tasa de Rebote')
plt.show()

plt.figure(figsize=(10, 6))

sns.scatterplot(x='BounceRates', 
                y='ProductRelated_Duration', 
                hue='Revenue', 
                data=raw_dataset_mod,
                alpha=0.3) 

plt.title('Hipótesis: Duración vs. Tasa de Rebote (Coloreado por Compra)')
plt.xlabel('Tasa de Rebote (BounceRates)')
plt.ylabel('Duración en Productos (segundos)')
plt.legend(title='¿Compró? (Revenue)')
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ## Hipotesis 6 / Bivariada

# %% [markdown]
# H₀: no hay diferencias en la distribución (mediana) de PageValues entre compradores y no compradores.

# %% [markdown]
# H₁: la mediana de PageValues es mayor en las sesiones donde finalmente se realiza una compra.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro, levene, mannwhitneyu

compran = raw_dataset_mod[raw_dataset_mod["Revenue"] == True]["PageValues"]
no_compran = raw_dataset_mod[raw_dataset_mod["Revenue"] == False]["PageValues"]

# Test de normalidad (Shapiro-Wilk) -> Shapiro se aplica sobre muestras cuando N es muy grande
sample_compran = compran.sample(500, random_state=42)
sample_no_compran = no_compran.sample(500, random_state=42)
print()
print("Test de normalidad Shapiro-Wilk")
print("Compran:", shapiro(sample_compran))
print("No compran:",shapiro(sample_no_compran))
print()

# Test de homogeneidad de varianzas (Levene)
print("Test de homogeneidad de varianzas (Levene)")
print (levene(compran, no_compran))
print()

# Test Mann-Whitney U (bilateral)
mw = mannwhitneyu(compran, no_compran, alternative="two-sided")
print()
print("Test Mann-Whitney U (bilateral)")
print(mw)

alpha = 0.05

print()
print("Conclusión de la hipótesis")
if mw.pvalue < alpha:
    print(f"Se rechaza H0 (p-value = {mw.pvalue:.4f}).")
    print("Las distribuciones de PageValues difieren significativamente entre ambos grupos.")
else:
    print(f"No se puede rechazar H0 (p-value = {mw.pvalue:.4f}).")
    print("No hay evidencia estadística de diferencias en PageValues entre los grupos.")
# Out:
# Test de normalidad Shapiro-Wilk
# Compran: ShapiroResult(statistic=np.float64(0.6662691393292436), pvalue=np.float64(3.7854384675498486e-30))
# No compran: ShapiroResult(statistic=np.float64(0.3204386201903572), pvalue=np.float64(2.87567040249507e-39))
#
# Test de homogeneidad de varianzas (Levene)
# LeveneResult(statistic=np.float64(3176.699898711489), pvalue=np.float64(0.0))
#
#
# Test Mann-Whitney U (bilateral)
# MannwhitneyuResult(statistic=np.float64(16942767.0), pvalue=np.float64(0.0))
#
# Conclusión de la hipótesis
# Se rechaza H0 (p-value = 0.0000).
# Las distribuciones de PageValues difieren significativamente entre ambos grupos.

# %% [markdown]
# ### Graficos

# %%
# BOXPLOT
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=raw_dataset_mod,
    x="Revenue",
    y="PageValues",
    hue="Revenue",
    palette="Set2",
    legend=False
)
plt.title("Distribución de PageValues: Compradores vs No Compradores")
plt.xlabel("Revenue")
plt.ylabel("PageValues (Escala Logarítmica)")
plt.yscale('symlog') 
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# VIOLIN PLOT
plt.figure(figsize=(10,6))
sns.violinplot(
    data=raw_dataset_mod,
    x="Revenue",
    y="PageValues",
    hue="Revenue",
    palette="Set3",
    cut=0,
    legend=False
)
plt.title("Comparación completa de la distribución de PageValues")
plt.xlabel("Revenue")
plt.ylabel("PageValues")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# # DataFrame con todos los cambios realizados

# %%
# guardamos el dataframe en un archivo csv
raw_dataset_mod.to_csv("online_shoppers_intention_mod.csv")
